# %% [markdown]
# # Autonomous IT Incident Triage Agent (OpsSentinel)\n\n## Pitch\n\nProblem: IT operations teams and SREs are flooded with alerts from monitoring systems (Zabbix), infrastructure orchestration (Proxmox), and network devices (OPNsENSE). Each alert requires contextual investigation — recent logs, VM status, resource metrics — before diagnosing and remediating. Manual triage is slow, inconsistent, and error-prone, increasing downtime and human workload.\n

# %%
# Demo cell: run the mock agent demo (ensure src is in the notebook path)\nimport sys\nsys.path.append('/mnt/data/agents-capstone')\nfrom src.agent.agent_main import run_demo\nrun_demo()\n

# %% [markdown]
# ## How to reproduce locally\n1. Clone the repo.\n2. Create venv and `pip install -r requirements.txt`.\n3. Run `python src/agent/agent_main.py`\n
